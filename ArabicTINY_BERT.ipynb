# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammed-saeed/Arabic-Distil-Bert/blob/main/ArabicTINY_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --user=msaeed --ask-password https://oscar-prive.huma-num.fr/2109/packaged/ar/ar_part_1.txt.gz
# Out:
# Password for user ‘msaeed’:
# --2022-05-30 07:44:40--  https://oscar-prive.huma-num.fr/2109/packaged/ar/ar_part_1.txt.gz
# Resolving oscar-prive.huma-num.fr (oscar-prive.huma-num.fr)... 134.158.33.192
# Connecting to oscar-prive.huma-num.fr (oscar-prive.huma-num.fr)|134.158.33.192|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Authentification LDAP"
# Reusing existing connection to oscar-prive.huma-num.fr:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 289845638 (276M) [application/x-gzip]
# Saving to: ‘ar_part_1.txt.gz’
#
# ar_part_1.txt.gz    100%[===================>] 276.42M  25.9MB/s    in 11s
#
# 2022-05-30 07:44:53 (24.0 MB/s) - ‘ar_part_1.txt.gz’ saved [289845638/289845638]

# %%
# %%capture
# !cd ~
# !git clone https://github.com/huggingface/datasets.git
# %cd /content/datasets
# %pip install -e .
# %pwd
# %cd /content
# !git clone https://github.com/huggingface/transformers.git
# %cd /content/transformers
# %pip install .
# %cd /content

# %%
# !gzip -d   "/content/ar_part_1.txt.gz"

# %%
train_text = ""
with open("/content/ar_part_1.txt", "r") as fb:
  train_text = fb.readlines()

with open("/content/train_file.txt", "w") as fb:
  fb.writelines(train_text[:1000])

# %%
# !python3 /content/transformers/examples/xla_spawn.py --num_cores=8 transformers/examples/language-modeling/run_mlm.py --model_name_or_path init_distilbert --train_file 30gig_files/ar_file1.txt --do_train --do_eval  --output_dir output --validation_split_percentage=2 --per_device_eval_batch_size=2048 --num_train_epochs=1 --line_by_line
# Out:
# python3: can't open file '/content/transformers/examples/xla_spawn.py': [Errno 2] No such file or directory

# %%
# !python3 run_clm.py --model_type gpt2 --tokenizer_name gpt2 --config_overrides="n_embd=1024,n_head=16,n_layer=48,n_positions=102"
# Out:
# python3: can't open file 'run_clm.py': [Errno 2] No such file or directory

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
# Out:
# Downloading:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/491 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/326k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# !python3 /content/transformers/examples/pytorch/language-modeling/run_mlm.py --train_file /content/train_file.txt  --output_dir /content/test-mlm --tokenizer_name "asafaya/bert-base-arabic" --model_type distilbert --do_train --mlm_probability 0.0 --num_train_epochs=3.0 --tpu_metrics_debug True --tpu_num_cores 8  --config_overrides="n_heads=6,n_layers=3" --overwrite_output_dir=True
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/training_args.py:1090: FutureWarning: using `--tpu_metrics_debug` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--debug tpu_metrics_debug` instead
#   FutureWarning,
# 05/30/2022 09:47:42 - WARNING - __main__ - Process rank: -1, device: cpu, n_gpu: 0distributed training: False, 16-bits training: False
# 05/30/2022 09:47:42 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=0,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[<DebugOption.TPU_METRICS_DEBUG: 'tpu_metrics_debug'>],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=False,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# ...

# %%
#trying to load our own tokenizer
# !python3 /content/transformers/examples/pytorch/language-modeling/run_mlm.py --train_file /content/train_file.txt  --output_dir /content/test-mlm  --model_type distilbert --do_train --mlm_probability 0.0 --num_train_epochs=1.0 --tpu_metrics_debug True --tpu_num_cores 8 --tokenizer /content/vocab.txt  --config_overrides="n_heads=6,n_layers=3" --overwrite_output_dir=True
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/training_args.py:1090: FutureWarning: using `--tpu_metrics_debug` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--debug tpu_metrics_debug` instead
#   FutureWarning,
# 05/30/2022 08:31:16 - WARNING - __main__ - Process rank: -1, device: cpu, n_gpu: 0distributed training: False, 16-bits training: False
# 05/30/2022 08:31:16 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=0,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[<DebugOption.TPU_METRICS_DEBUG: 'tpu_metrics_debug'>],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=False,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# ...

# %%
# !python3 /content/transformers/examples/pytorch/language-modeling/run_mlm.py --train_file output.txt --model_type distilbert --tokenizer_name distilbert-base-uncased --do_train --mlm_probability 0.0 --tpu_metrics_debug True --tpu_num_cores 8 --output_dir /content/test-mlm

# %%
# !rm -rf "/content/test-mlm"
